# %%
from __future__ import division
import cv2
import numpy as np
import pandas as pd
from tqdm import tqdm
from keras.models import Sequential, Model, load_model
from keras.layers import Dense, Dropout, Flatten, Merge, merge
from keras.layers.merge import Concatenate
from keras.layers import Input, Activation, Dense, Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D, AveragePooling2D
from keras.layers.normalization import BatchNormalization
from keras.layers.core import Lambda
from keras import backend as K
import os
from sklearn.utils import shuffle
import random
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import fbeta_score
from keras.optimizers import Adam, SGD
from keras import applications

import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
tf
# Out:
# <module 'tensorflow' from '/usr/local/lib/python2.7/dist-packages/tensorflow/__init__.pyc'>

# %%
def make_parallel(model, gpu_count):
    def get_slice(data, idx, parts):
        shape = tf.shape(data)
        size = tf.concat([ shape[:1] // parts, shape[1:] ],axis=0)
        stride = tf.concat([ shape[:1] // parts, shape[1:]*0 ],axis=0)
        start = stride * idx
        return tf.slice(data, start, size)

    outputs_all = []
    for i in range(len(model.outputs)):
        outputs_all.append([])

    #Place a copy of the model on each GPU, each getting a slice of the batch
    for i in range(gpu_count):
        with tf.device('/gpu:%d' % i):
            with tf.name_scope('tower_%d' % i) as scope:

                inputs = []
                #Slice each input into a piece for processing on this GPU
                for x in model.inputs:
                    input_shape = tuple(x.get_shape().as_list())[1:]
                    slice_n = Lambda(get_slice, output_shape=input_shape, arguments={'idx':i,'parts':gpu_count})(x)
                    inputs.append(slice_n)                

                outputs = model(inputs)
                
                if not isinstance(outputs, list):
                    outputs = [outputs]
                
                #Save all the outputs for merging back together later
                for l in range(len(outputs)):
                    outputs_all[l].append(outputs[l])

    # merge outputs on CPU
    with tf.device('/cpu:0'):
        merged = []
        for outputs in outputs_all:
            merged.append(Concatenate(axis=0)(outputs))
            
        return Model(inputs=model.inputs, outputs=merged)

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "0, 1"

def fbeta_loss(y_true, y_pred):
    beta_squared = 4

    tp = K.sum(y_true * y_pred) + K.epsilon()
    fp = K.sum(y_pred) - tp
    fn = K.sum(y_true) - tp

    precision = tp / (tp + fp)
    recall = tp / (tp + fn)

    result = 1 - (beta_squared + 1) * (precision * recall) / (beta_squared * precision + recall + K.epsilon())

    return result

def fbeta_score_K(y_true, y_pred):
    beta_squared = 4

    tp = K.sum(y_true * y_pred) + K.epsilon()
    fp = K.sum(y_pred) - tp
    fn = K.sum(y_true) - tp

    precision = tp / (tp + fp)
    recall = tp / (tp + fn)

    result = (beta_squared + 1) * (precision * recall) / (beta_squared * precision + recall + K.epsilon())

    return result

def rotate(img):
    rows = img.shape[0]
    cols = img.shape[1]
    angle = np.random.choice((10, 20, 30))#, 40, 50, 60, 70, 80, 90))
    rotation_M = cv2.getRotationMatrix2D((cols / 2, rows / 2), angle, 1)
    img = cv2.warpAffine(img, rotation_M, (cols, rows))
    return img

def rotate_bound(image, size):
    #credits http://www.pyimagesearch.com/2017/01/02/rotate-images-correctly-with-opencv-and-python/
    (h, w) = image.shape[:2]
    (cX, cY) = (w // 2, h // 2)

    angle = np.random.randint(10,180)

    M = cv2.getRotationMatrix2D((cX, cY), -angle, 1.0)
    cos = np.abs(M[0, 0])
    sin = np.abs(M[0, 1])

    # compute the new bounding dimensions of the image
    nW = int((h * sin) + (w * cos))
    nH = int((h * cos) + (w * sin))

    # adjust the rotation matrix to take into account translation
    M[0, 2] += (nW / 2) - cX
    M[1, 2] += (nH / 2) - cY

    output = cv2.resize(cv2.warpAffine(image, M, (nW, nH)), (size, size))
    return output

def perspective(img):
    rows = img.shape[0]
    cols = img.shape[1]

    shrink_ratio1 = np.random.randint(low=85, high=110, dtype=int) / 100
    shrink_ratio2 = np.random.randint(low=85, high=110, dtype=int) / 100

    zero_point = rows - np.round(rows * shrink_ratio1, 0)
    max_point_row = np.round(rows * shrink_ratio1, 0)
    max_point_col = np.round(cols * shrink_ratio2, 0)

    src = np.float32([[zero_point, zero_point], [max_point_row-1, zero_point], [zero_point, max_point_col+1], [max_point_row-1, max_point_col+1]])
    dst = np.float32([[0, 0], [rows, 0], [0, cols], [rows, cols]])

    perspective_M = cv2.getPerspectiveTransform(src, dst)

    img = cv2.warpPerspective(img, perspective_M, (cols,rows))#, borderValue=mean_pix)
    return img

def shift(img):
    rows = img.shape[0]
    cols = img.shape[1]

    shift_ratio1 = (random.random() * 2 - 1) * np.random.randint(low=3, high=15, dtype=int)
    shift_ratio2 = (random.random() * 2 - 1) * np.random.randint(low=3, high=15, dtype=int)

    shift_M = np.float32([[1,0,shift_ratio1], [0,1,shift_ratio2]])
    img = cv2.warpAffine(img, shift_M, (cols, rows))#, borderValue=mean_pix)
    return img

# %%
def batch_generator_train(zip_list, img_size, batch_size, is_train=True, shuffle=True):
    number_of_batches = np.ceil(len(zip_list) / batch_size)
    if shuffle == True:
        random.shuffle(zip_list)
    counter = 0
    offsets = np.arange(0, 12)
    while True:
        if shuffle == True:
            random.shuffle(zip_list)
        batch_files = zip_list[batch_size*counter:batch_size*(counter+1)]
        image_list = []
        mask_list = []

        for file, mask in batch_files:

            image = cv2.imread(file) #cv2.resize(cv2.imread(file), (img_size,img_size)) / 255.
            x, y = np.random.choice(offsets, 2)
            image = image[x:x+img_size, y:y+img_size]
            image = image[:, :, [2, 1, 0]] - mean_pix

            rnd_flip = np.random.randint(2, dtype=int)
            rnd_rotate = np.random.randint(2, dtype=int)
            rnd_zoom = np.random.randint(2, dtype=int)
            rnd_shift = np.random.randint(2, dtype=int)

            if (rnd_flip == 1) & (is_train == True):
                rnd_flip = np.random.randint(3, dtype=int) - 1
                image = cv2.flip(image, rnd_flip)

            if (rnd_rotate == 1) & (is_train == True):
                image = rotate_bound(image, img_size)

            if (rnd_zoom == 1) & (is_train == True):
                image = perspective(image)

            if (rnd_shift == 1) & (is_train == True):
                image = shift(image)

            image_list.append(image)
            mask_list.append(mask)

        counter += 1
        image_list = np.array(image_list)
        mask_list = np.array(mask_list)

        yield (image_list, mask_list)

        if counter == number_of_batches:
            if shuffle == True:
                random.shuffle(zip_list)
            counter = 0

def batch_generator_test(zip_list, img_size, batch_size, shuffle=True):
    number_of_batches = int(np.ceil(len(zip_list)/2))
    print(len(zip_list), number_of_batches)
    counter = 0
    if shuffle:
        random.shuffle(zip_list)
    while True:
        batch_files = zip_list[2*counter:2*(counter+1)]
        image_list = []
        mask_list = []
        
        print 'counter: ' + str(counter)

        for file, mask in batch_files:
            
            print file

            image = cv2.resize(cv2.imread(file), (img_size, img_size))
            image = image[:, :, [2, 1, 0]] - mean_pix
            image_list.append(image)
            mask_list.append(mask)

        counter += 1
        image_list = np.array(image_list)
        mask_list = np.array(mask_list)

        yield (image_list, mask_list)

        if counter == number_of_batches:
            random.shuffle(zip_list)
            counter = 0

def predict_generator(files, img_size, batch_size):
    number_of_batches = np.ceil(len(files) / batch_size)
    print(len(files), number_of_batches)
    counter = 0
    int_counter = 0

    while True:
            beg = batch_size * counter
            end = batch_size * (counter + 1)
            batch_files = files[beg:end]
            image_list = []

            for file in batch_files:
                int_counter += 1
                image = cv2.resize(cv2.imread(file), (img_size, img_size))
                image = image[:, :, [2, 1, 0]] - mean_pix

                rnd_flip = np.random.randint(2, dtype=int)
                rnd_rotate = np.random.randint(2, dtype=int)
                rnd_zoom = np.random.randint(2, dtype=int)
                rnd_shift = np.random.randint(2, dtype=int)

                if rnd_flip == 1:
                    rnd_flip = np.random.randint(3, dtype=int) - 1
                    image = cv2.flip(image, rnd_flip)

                if rnd_rotate == 1:
                    image = rotate_bound(image, img_size)

                if rnd_zoom == 1:
                    image = perspective(image)

                if rnd_shift == 1:
                    image = shift(image)

                image_list.append(image)

            counter += 1

            image_list = np.array(image_list)

            yield (image_list)


def f2_score(y_true, y_pred):
    y_true, y_pred, = np.array(y_true), np.array(y_pred)
    score = fbeta_score(y_true, y_pred, beta=2, average='samples')
    return score

# %%
GLOBAL_PATH = '/home/user/data/amazon_planet/'
TRAIN_FOLDER = '/home/user/data/amazon_planet/train-jpg/' #All train files resized to 224*224
TEST_FOLDER = '/home/user/data/amazon_planet/test-jpg/' #All test files in one folder
F_CLASSES = GLOBAL_PATH + 'train_v2.csv'

df_train = pd.read_csv(F_CLASSES)
df_test = pd.read_csv(GLOBAL_PATH + 'sample_submission_v2.csv')

labels = ['blow_down',
          'bare_ground',
          'conventional_mine',
          'blooming',
          'cultivation',
          'artisinal_mine',
          'haze',
          'primary',
          'slash_burn',
          'habitation',
          'clear',
          'road',
          'selective_logging',
          'partly_cloudy',
          'agriculture',
          'water',
          'cloudy']
label_map = {'agriculture': 14,
             'artisinal_mine': 5,
             'bare_ground': 1,
             'blooming': 3,
             'blow_down': 0,
             'clear': 10,
             'cloudy': 16,
             'conventional_mine': 2,
             'cultivation': 4,
             'habitation': 9,
             'haze': 6,
             'partly_cloudy': 13,
             'primary': 7,
             'road': 11,
             'selective_logging': 12,
             'slash_burn': 8,
             'water': 15}

flatten = lambda l: [item for sublist in l for item in sublist]

# %%
x_train = []
x_test = []
y_train = []


for f, tags in tqdm(df_train.values, miniters=1000):
    img = TRAIN_FOLDER + '{}.jpg'.format(f)
    targets = np.zeros(17)
    for t in tags.split(' '):
        targets[label_map[t]] = 1
    x_train.append(img)
    y_train.append(targets)
# Out:
# 100%|██████████| 40479/40479 [00:00<00:00, 146141.52it/s]

# %%
x_train, x_holdout, y_train, y_holdout = x_train[3000:-1], x_train[:3000], y_train[3000:-1], y_train[:3000]

x_train, y_train = shuffle(x_train, y_train, random_state = 24)

part = 0.85
split = int(round(part*len(y_train)))
x_train, x_valid, y_train, y_valid = x_train[:split], x_train[split:], y_train[:split], y_train[split:]
print('x tr: ', len(x_train))
# Out:
# ('x tr: ', 31856)

# %%
#define callbacks
callbacks = [ModelCheckpoint('amazon_2007.hdf5', monitor='val_loss', save_best_only=True, verbose=2, save_weights_only=False),
             ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, verbose=1, mode='auto', epsilon=0.0001, cooldown=0, min_lr=0.0000001),
             EarlyStopping(monitor='val_loss', patience=5, verbose=0)]

# %%
BATCH = 128
IMG_SIZE = 224
mean_pix = np.array([102.9801, 115.9465, 122.7717]) #It is BGR

# %%
#Compile model and set non-top layets non-trainable (warm-up)
base_model = applications.resnet50.ResNet50(include_top=False, input_shape=(IMG_SIZE,IMG_SIZE,3), pooling='avg', weights='imagenet')
for layer in base_model.layers:
    layer.trainable = False

# %%
x = base_model.output
x = Dense(2048, activation='relu')(x)
x = Dropout(0.25)(x)
output = Dense(17, activation='sigmoid')(x)

# %%
model = Model(inputs=base_model.inputs, outputs=output)
model = make_parallel(model, 2)

# %%
model.summary()

# %%
optimizer = Adam(0.001, decay=0.0003)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy', fbeta_score_K])

# %%
model.fit_generator(generator=batch_generator_train(list(zip(x_train, y_train)), IMG_SIZE, BATCH),
                          steps_per_epoch=np.ceil(len(x_train)/BATCH),
                          epochs=1,
                          verbose=1,
                          validation_data=batch_generator_train(list(zip(x_valid, y_valid)), IMG_SIZE, 16),
                          validation_steps=np.ceil(len(x_valid)/16),
                          callbacks=callbacks,
                          initial_epoch=0,
                           use_multiprocessing=True,
                           workers=16)

# %%
#Compile model and set all layers trainable
optimizer = Adam(0.0001, decay=0.00000001)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy', fbeta_score_K])
model.load_weights('amazon_2007.hdf5', by_name=True)
for layer in base_model.layers:
    layer.trainable = True

# %%
BATCH = 32
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy', fbeta_score_K])
model.fit_generator(generator=batch_generator_train(list(zip(x_train, y_train)), IMG_SIZE, BATCH),
                          steps_per_epoch=np.ceil(len(x_train)/BATCH),
                          epochs=50,
                          verbose=1,
                          validation_data=batch_generator_train(list(zip(x_valid, y_valid)), IMG_SIZE, 16),
                          validation_steps=np.ceil(len(x_valid)/16),
                          callbacks=callbacks,
                          initial_epoch=0,
                           use_multiprocessing=True,
                           workers=16)

# %%
#Compile model and set all layers trainable
model=load_model('amazon_2007.hdf5', custom_objects={"tf": tf,"fbeta_score_K": fbeta_score_K})
# optimizer = Adam(1.6000000187e-07, decay=0.00000001)
# model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy', fbeta_score_K])
# model.load_weights('amazon_2007.hdf5', by_name=True)
# for layer in base_model.layers:
#     layer.trainable = True

# %%
optimizer = Adam(1.0e-06, decay=0.00000001)
model = make_parallel(model, 2)
# model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy', fbeta_score_K])

# %%
BATCH = 32
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy', fbeta_score_K])
model.fit_generator(generator=batch_generator_train(list(zip(x_train, y_train)), IMG_SIZE, BATCH),
                          steps_per_epoch=np.ceil(len(x_train)/BATCH),
                          epochs=50,
                          verbose=1,
                          validation_data=batch_generator_train(list(zip(x_valid, y_valid)), IMG_SIZE, 16),
                          validation_steps=np.ceil(len(x_valid)/16),
                          callbacks=callbacks,
                          initial_epoch=0,
                           use_multiprocessing=True,
                           workers=32)
# Out:
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/Rank with an op tower_0_3/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/range_1/start with an op tower_0_3/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/range_1/delta with an op tower_0_3/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/range_1 with an op tower_0_3/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/ListDiff with an op tower_0_3/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/concat/axis with an op tower_0_3/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/concat with an op tower_0_3/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/Gather with an op tower_0_3/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/Const with an op tower_0_3/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/Prod with an op tower_0_3/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/Gather_1 with an op tower_0_3/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/Const_1 with an op tower_0_3/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/Prod_1 with an op tower_0_3/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/Rank with an op tower_0_3/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/range_1/start with an op tower_0_3/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/range_1/delta with an op tower_0_3/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/range_1 with an op tower_0_3/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/ListDiff with an op tower_0_3/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/concat/axis with an op tower_0_3/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/concat with an op tower_0_3/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/Gather with an op tower_0_3/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/Const with an op tower_0_3/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/Prod with an op tower_0_3/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/Gather_1 with an op tower_0_3/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/Const_1 with an op tower_0_3/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/Prod_1 with an op tower_0_3/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/Rank with an op tower_1_2/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/range_1/start with an op tower_1_2/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/range_1/delta with an op tower_1_2/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/range_1 with an op tower_1_2/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/ListDiff with an op tower_1_2/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/concat/axis with an op tower_1_2/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/concat with an op tower_1_2/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/Gather with an op tower_1_2/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/Const with an op tower_1_2/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/Prod with an op tower_1_2/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/Gather_1 with an op tower_1_2/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/Const_1 with an op tower_1_2/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/Prod_1 with an op tower_1_2/model_2/model_1_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/Rank with an op tower_1_2/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/range_1/start with an op tower_1_2/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/range_1/delta with an op tower_1_2/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/range_1 with an op tower_1_2/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/ListDiff with an op tower_1_2/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/concat/axis with an op tower_1_2/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/concat with an op tower_1_2/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/Gather with an op tower_1_2/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/Const with an op tower_1_2/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/Prod with an op tower_1_2/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/Gather_1 with an op tower_1_2/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/Const_1 with an op tower_1_2/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count_grad/Prod_1 with an op tower_1_2/model_2/model_1/bn5c_branch2c/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/Rank with an op tower_0_3/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/range_1/start with an op tower_0_3/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/range_1/delta with an op tower_0_3/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/range_1 with an op tower_0_3/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/ListDiff with an op tower_0_3/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/concat/axis with an op tower_0_3/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/concat with an op tower_0_3/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/Gather with an op tower_0_3/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/Const with an op tower_0_3/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/Prod with an op tower_0_3/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/Gather_1 with an op tower_0_3/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/Const_1 with an op tower_0_3/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/Prod_1 with an op tower_0_3/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/Rank with an op tower_0_3/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/range_1/start with an op tower_0_3/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/range_1/delta with an op tower_0_3/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/range_1 with an op tower_0_3/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/ListDiff with an op tower_0_3/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/concat/axis with an op tower_0_3/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/concat with an op tower_0_3/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/Gather with an op tower_0_3/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/Const with an op tower_0_3/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/Prod with an op tower_0_3/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/Gather_1 with an op tower_0_3/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/Const_1 with an op tower_0_3/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/Prod_1 with an op tower_0_3/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/Rank with an op tower_1_2/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/range_1/start with an op tower_1_2/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/range_1/delta with an op tower_1_2/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/range_1 with an op tower_1_2/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/ListDiff with an op tower_1_2/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/concat/axis with an op tower_1_2/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/concat with an op tower_1_2/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/Gather with an op tower_1_2/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/Const with an op tower_1_2/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/Prod with an op tower_1_2/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/Gather_1 with an op tower_1_2/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/Const_1 with an op tower_1_2/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/Prod_1 with an op tower_1_2/model_2/model_1_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/Rank with an op tower_1_2/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/range_1/start with an op tower_1_2/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/range_1/delta with an op tower_1_2/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/range_1 with an op tower_1_2/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/ListDiff with an op tower_1_2/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/concat/axis with an op tower_1_2/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/concat with an op tower_1_2/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/Gather with an op tower_1_2/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/Const with an op tower_1_2/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/Prod with an op tower_1_2/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/Gather_1 with an op tower_1_2/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/Const_1 with an op tower_1_2/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count_grad/Prod_1 with an op tower_1_2/model_2/model_1/bn5c_branch2b/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/Rank with an op tower_0_3/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/range_1/start with an op tower_0_3/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/range_1/delta with an op tower_0_3/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/range_1 with an op tower_0_3/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/ListDiff with an op tower_0_3/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/concat/axis with an op tower_0_3/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/concat with an op tower_0_3/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/Gather with an op tower_0_3/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/Const with an op tower_0_3/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/Prod with an op tower_0_3/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/Gather_1 with an op tower_0_3/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/Const_1 with an op tower_0_3/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/Prod_1 with an op tower_0_3/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/Rank with an op tower_0_3/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/range_1/start with an op tower_0_3/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/range_1/delta with an op tower_0_3/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/range_1 with an op tower_0_3/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/ListDiff with an op tower_0_3/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/concat/axis with an op tower_0_3/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/concat with an op tower_0_3/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/Gather with an op tower_0_3/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/Const with an op tower_0_3/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/Prod with an op tower_0_3/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/Gather_1 with an op tower_0_3/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/Const_1 with an op tower_0_3/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/Prod_1 with an op tower_0_3/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/Rank with an op tower_1_2/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/range_1/start with an op tower_1_2/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/range_1/delta with an op tower_1_2/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/range_1 with an op tower_1_2/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/ListDiff with an op tower_1_2/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/concat/axis with an op tower_1_2/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/concat with an op tower_1_2/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/Gather with an op tower_1_2/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/Const with an op tower_1_2/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/Prod with an op tower_1_2/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/Gather_1 with an op tower_1_2/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/Const_1 with an op tower_1_2/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/Prod_1 with an op tower_1_2/model_2/model_1_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/Rank with an op tower_1_2/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/range_1/start with an op tower_1_2/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/range_1/delta with an op tower_1_2/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/range_1 with an op tower_1_2/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/ListDiff with an op tower_1_2/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/concat/axis with an op tower_1_2/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count_grad/concat with an op tower_1_2/model_2/model_1/bn5c_branch2a/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# ...
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn_conv1/moments/sufficient_statistics/count_grad/concat with an op tower_0_3/model_2/model_1/bn_conv1/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn_conv1/moments/sufficient_statistics/count_grad/Gather with an op tower_0_3/model_2/model_1/bn_conv1/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn_conv1/moments/sufficient_statistics/count_grad/Const with an op tower_0_3/model_2/model_1/bn_conv1/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn_conv1/moments/sufficient_statistics/count_grad/Prod with an op tower_0_3/model_2/model_1/bn_conv1/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn_conv1/moments/sufficient_statistics/count_grad/Gather_1 with an op tower_0_3/model_2/model_1/bn_conv1/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn_conv1/moments/sufficient_statistics/count_grad/Const_1 with an op tower_0_3/model_2/model_1/bn_conv1/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_0_3/model_2/model_1/bn_conv1/moments/sufficient_statistics/count_grad/Prod_1 with an op tower_0_3/model_2/model_1/bn_conv1/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:0. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn_conv1/moments/sufficient_statistics/count_grad/Rank with an op tower_1_2/model_2/model_1_1/bn_conv1/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn_conv1/moments/sufficient_statistics/count_grad/range_1/start with an op tower_1_2/model_2/model_1_1/bn_conv1/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn_conv1/moments/sufficient_statistics/count_grad/range_1/delta with an op tower_1_2/model_2/model_1_1/bn_conv1/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn_conv1/moments/sufficient_statistics/count_grad/range_1 with an op tower_1_2/model_2/model_1_1/bn_conv1/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn_conv1/moments/sufficient_statistics/count_grad/ListDiff with an op tower_1_2/model_2/model_1_1/bn_conv1/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn_conv1/moments/sufficient_statistics/count_grad/concat/axis with an op tower_1_2/model_2/model_1_1/bn_conv1/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn_conv1/moments/sufficient_statistics/count_grad/concat with an op tower_1_2/model_2/model_1_1/bn_conv1/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn_conv1/moments/sufficient_statistics/count_grad/Gather with an op tower_1_2/model_2/model_1_1/bn_conv1/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn_conv1/moments/sufficient_statistics/count_grad/Const with an op tower_1_2/model_2/model_1_1/bn_conv1/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn_conv1/moments/sufficient_statistics/count_grad/Prod with an op tower_1_2/model_2/model_1_1/bn_conv1/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn_conv1/moments/sufficient_statistics/count_grad/Gather_1 with an op tower_1_2/model_2/model_1_1/bn_conv1/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn_conv1/moments/sufficient_statistics/count_grad/Const_1 with an op tower_1_2/model_2/model_1_1/bn_conv1/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1_1/bn_conv1/moments/sufficient_statistics/count_grad/Prod_1 with an op tower_1_2/model_2/model_1_1/bn_conv1/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn_conv1/moments/sufficient_statistics/count_grad/Rank with an op tower_1_2/model_2/model_1/bn_conv1/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn_conv1/moments/sufficient_statistics/count_grad/range_1/start with an op tower_1_2/model_2/model_1/bn_conv1/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn_conv1/moments/sufficient_statistics/count_grad/range_1/delta with an op tower_1_2/model_2/model_1/bn_conv1/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn_conv1/moments/sufficient_statistics/count_grad/range_1 with an op tower_1_2/model_2/model_1/bn_conv1/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn_conv1/moments/sufficient_statistics/count_grad/ListDiff with an op tower_1_2/model_2/model_1/bn_conv1/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn_conv1/moments/sufficient_statistics/count_grad/concat/axis with an op tower_1_2/model_2/model_1/bn_conv1/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn_conv1/moments/sufficient_statistics/count_grad/concat with an op tower_1_2/model_2/model_1/bn_conv1/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn_conv1/moments/sufficient_statistics/count_grad/Gather with an op tower_1_2/model_2/model_1/bn_conv1/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn_conv1/moments/sufficient_statistics/count_grad/Const with an op tower_1_2/model_2/model_1/bn_conv1/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn_conv1/moments/sufficient_statistics/count_grad/Prod with an op tower_1_2/model_2/model_1/bn_conv1/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn_conv1/moments/sufficient_statistics/count_grad/Gather_1 with an op tower_1_2/model_2/model_1/bn_conv1/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn_conv1/moments/sufficient_statistics/count_grad/Const_1 with an op tower_1_2/model_2/model_1/bn_conv1/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# WARNING:tensorflow:Tried to colocate gradients_2/tower_1_2/model_2/model_1/bn_conv1/moments/sufficient_statistics/count_grad/Prod_1 with an op tower_1_2/model_2/model_1/bn_conv1/moments/sufficient_statistics/count that had a different device: /device:CPU:0 vs /device:GPU:1. Ignoring colocation property.
# /usr/local/lib/python2.7/dist-packages/Keras-2.0.5-py2.7.egg/keras/engine/training.py:1775: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the`keras.utils.Sequence class.
# Epoch 1/50
# 995/996 [============================>.] - ETA: 0s - loss: 0.0814 - acc: 0.9687 - fbeta_score_K: 0.8602
# /usr/local/lib/python2.7/dist-packages/Keras-2.0.5-py2.7.egg/keras/engine/training.py:1926: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the`keras.utils.Sequence class.
# Epoch 00000: val_loss improved from inf to 0.09572, saving model to amazon_2007.hdf5
# 996/996 [==============================] - 519s - loss: 0.0814 - acc: 0.9687 - fbeta_score_K: 0.8602 - val_loss: 0.0957 - val_acc: 0.9659 - val_fbeta_score_K: 0.8536
# Epoch 2/50
# 995/996 [============================>.] - ETA: 0s - loss: 0.
50
# 995/996 [============================>.] - ETA: 0s - loss: 0.0804 - acc: 0.9692 - fbeta_score_K: 0.8614Epoch 00010: val_loss did not improve
# 996/996 [==============================] - 482s - loss: 0.0804 - acc: 0.9692 - fbeta_score_K: 0.8614 - val_loss: 0.0942 - val_acc: 0.9646 - val_fbeta_score_K: 0.8539
# Epoch 12/50
# 995/996 [============================>.] - ETA: 0s - loss: 0.0811 - acc: 0.9687 - fbeta_score_K: 0.8607Epoch 00011: val_loss did not improve
#
# Epoch 00011: reducing learning rate to 1e-07.
# 996/996 [==============================] - 483s - loss: 0.0811 - acc: 0.9687 - fbeta_score_K: 0.8607 - val_loss: 0.0945 - val_acc: 0.9657 - val_fbeta_score_K: 0.8551
# Epoch 13/50
# 995/996 [============================>.] - ETA: 0s - loss: 0.0810 - acc: 0.9690 - fbeta_score_K: 0.8614Epoch 00012: val_loss did not improve
# 996/996 [==============================] - 481s - loss: 0.0810 - acc: 0.9690 - fbeta_score_K: 0.8614 - val_loss: 0.0961 - val_acc: 0.9653 - val_fbeta_score_K: 0.8531
# Epoch 14/50
# 995/996 [============================>.] - ETA: 0s - loss: 0.0811 - acc: 0.9690 - fbeta_score_K: 0.8608Epoch 00013: val_loss did not improve
# 996/996 [==============================] - 483s - loss: 0.0811 - acc: 0.9690 - fbeta_score_K: 0.8608 - val_loss: 0.1000 - val_acc: 0.9637 - val_fbeta_score_K: 0.8466
# Epoch 15/50
# 995/996 [============================>.] - ETA: 0s - loss: 0.0804 - acc: 0.9690 - fbeta_score_K: 0.8618Epoch 00014: val_loss did not improve
# 996/996 [==============================] - 481s - loss: 0.0804 - acc: 0.9691 - fbeta_score_K: 0.8619 - val_loss: 0.0962 - val_acc: 0.9651 - val_fbeta_score_K: 0.8501

# %%
model.load_weights('amazon_2007.hdf5')


x_val = []
y_val = []
x_hld = []
y_hld = []
x_test = []
y_test = []

# %%
#====================== validation set est =================================
for f, tags in tqdm(list(zip(x_valid, y_valid)), miniters=1000):
    y_val.append(tags)

p_valid = model.predict_generator(batch_generator_test(list(zip(x_valid, y_valid)), IMG_SIZE, 4, shuffle=False),
                                  steps=int(np.ceil(len(x_valid)/4)),
                                 verbose=1)

print('val_set: ', fbeta_score(np.array(y_val), np.array(p_valid) > 0.2, beta=2, average='samples'))
#===========================================================================
# Out:
# 100%|██████████| 5622/5622 [00:00<00:00, 673859.83it/s]
# (5622, 1406)
# counter: 0
# counter: 1
# counter: 2
# counter: 3
# counter: 4
# counter: 5
# counter: 6
# counter: 7
# counter: 8
# counter: 9
# counter: 10
#    1/1406 [..............................] - ETA: 222s
# counter: 11
#    2/1406 [..............................] - ETA: 175scounter: 12
#    3/1406 [..............................] - ETA: 183scounter: 13
#    4/1406 [..............................] - ETA: 181scounter: 14
#    5/1406 [..............................] - ETA: 176scounter: 15
#    6/1406 [..............................] - ETA: 171scounter: 16
#    7/1406 [..............................] - ETA: 167scounter: 17
#    8/1406 [..............................] - ETA: 160scounter: 18
#    9/1406 [..............................] - ETA: 158scounter: 19
#   10/1406 [..............................] - ETA: 156scounter: 20
#   11/1406 [..............................] - ETA: 154scounter: 21
#   12/1406 [..............................] - ETA: 152scounter: 22
#   13/1406 [..............................] - ETA: 152scounter: 23
#   14/1406 [..............................] - ETA: 150scounter: 24
#   15/1406 [..............................] - ETA: 149scounter: 25
#  453/1406 [========>.....................] - ETA: 92scounter: 463
#  454/1406 [========>.....................] - ETA: 92scounter: 464
#  455/1406 [========>.....................] - ETA: 92scounter: 465
#  456/1406 [========>.....................] - ETA: 91scounter: 466
#  457/1406 [========>.....................] - ETA: 91scounter: 467
#  458/1406 [========>.....................] - ETA: 91scounter: 468
#  459/1406 [========>.....................] - ETA: 91scounter: 469
#  460/1406 [========>.....................] - ETA: 91scounter: 470
#  461/1406 [========>.....................] - ETA: 91scounter: 471
#  462/1406 [========>.....................] - ETA: 91scounter: 472
#  463/1406 [========>.....................] - ETA: 91scounter: 473
#  464/1406 [========>.....................] - ETA: 91scounter: 474
#  465/1406 [========>.....................] - ETA: 91scounter: 475
#  466/1406 [========>.....................] - ETA: 91scounter: 476
#  467/1406 [========>.....................] - ETA: 91scounter: 477
#  468/1406 [========>.....................] - ETA: 90scounter: 478
#  469/1406 [=========>....................] - ETA: 90scounter: 479
#  470/1406 [=========>....................] - ETA: 90scounter: 480
#  471/1406 [=========>....................] - ETA: 90scounter: 481
#  472/1406 [=========>....................] - ETA: 90scounter: 482
#  473/1406 [=========>....................] - ETA: 90scounter: 483
#  474/1406 [=========>....................] - ETA: 90scounter: 484
#  475/1406 [=========>....................] - ETA: 90scounter: 485
#  476/1406 [=========>....................] - ETA: 90scounter: 486
#  477/1406 [=========>....................] - ETA: 90scounter: 487
#  478/1406 [=========>....................] - ETA: 89scounter: 488
#  479/1406 [=========>....................] - ETA: 89scounter: 489
#  480/1406 [=========>....................] - ETA: 89scounter: 490
#  481/1406 [=========>....................] - ETA: 89scounter: 491
#  482/1406 [=========>....................] - ETA: 89scounter: 492
#  483/1406 [=========>....................] - ETA: 89scounter: 493
#  484/1406 [=========>....................] - ETA: 89scounter: 494
#  485/1406 [=========>....................] - ETA: 89scounter: 495
#  486/1406 [=========>....................] - ETA: 89scounter: 496
#  487/1406 [=========>....................] - ETA: 89scounter: 497
#  488/1406 [=========>....................] - ETA: 88scounter: 498
#  489/1406 [=========>....................] - ETA: 88scounter: 499
#  490/1406 [=========>....................] - ETA: 88scounter: 500
#  491/1406 [=========>....................] - ETA: 88scounter: 501
#  492/1406 [=========>....................] - ETA: 88scounter: 502
#  493/1406 [=========>....................] - ETA: 88scounter: 503
#  494/1406 [=========>....................] - ETA: 88scounter: 504
#  495/1406 [=========>....................] - ETA: 88scounter: 505
#  496/1406 [=========>....................] - ETA: 88scounter: 506
#  497/1406 [=========>....................] - ETA: 88scounter: 507
#  498/1406 [=========>....................] - ETA: 87scounter: 508
#  499/1406 [=========>....................] - ETA: 87scounter: 509
#  500/1406 [=========>....................] - ETA: 87scounter: 510
#  501/1406 [=========>....................] - ETA: 87scounter: 511
#  502/1406 [=========>....................] - ETA: 87scounter: 512
#  503/1406 [=========>....................] - ETA: 87scounter: 513
#  504/1406 [=========>....................] - ETA: 87scounter: 514
#  505/1406 [=========>....................] - ETA: 87scounter: 515
#  506/1406 [=========>....................] - ETA: 87scounter: 516
#  561/1406 [==========>...................] - ETA: 81scounter: 571
#  562/1406 [==========>...................] - ETA: 81scounter: 572
#  563/1406 [===========>..................] - ETA: 81scounter: 573
#  564/1406 [===========>..................] - ETA: 81scounter: 574
#  565/1406 [===========>..................] - ETA: 81scounter: 575
#  566/1406 [===========>..................] - ETA: 81scounter: 576
#  567/1406 [===========>..................] - ETA: 81scounter: 577
#  568/1406 [===========>..................] - ETA: 81scounter: 578
#  569/1406 [===========>..................] - ETA: 81scounter: 579
#  570/1406 [===========>..................] - ETA: 80scounter: 580
#  571/1406 [===========>..................] - ETA: 80scounter: 581
#  572/1406 [===========>..................] - ETA: 80scounter: 582
#  573/1406 [===========>..................] - ETA: 80scounter: 583
#  574/1406 [===========>..................] - ETA: 80scounter: 584
#  575/1406 [===========>..................] - ETA: 80scounter: 585
#  576/1406 [===========>..................] - ETA: 80scounter: 586
#  577/1406 [===========>..................] - ETA: 80scounter: 587
#  578/1406 [===========>..................] - ETA: 80scounter: 588
#  579/1406 [===========>..................] - ETA: 80scounter: 589
#  580/1406 [===========>..................] - ETA: 79scounter: 590
#  581/1406 [===========>..................] - ETA: 79scounter: 591
#  582/1406 [===========>..................] - ETA: 79scounter: 592
#  583/1406 [===========>..................] - ETA: 79scounter: 593
#  584/1406 [===========>..................] - ETA: 79scounter: 594
#  585/1406 [===========>..................] - ETA: 79scounter: 595
#  586/1406 [===========>..................] - ETA: 79scounter: 596
#  587/1406 [===========>..................] - ETA: 79scounter: 597
#  588/1406 [===========>..................] - ETA: 79scounter: 598
#  589/1406 [===========>..................] - ETA: 79scounter: 599
#  590/1406 [===========>..................] - ETA: 79scounter: 600
#  591/1406 [===========>..................] - ETA: 78scounter: 601
#  592/1406 [===========>..................] - ETA: 78scounter: 602
#  593/1406 [===========>..................] - ETA: 78scounter: 603
#  594/1406 [===========>..................] - ETA: 78scounter: 604
#  595/1406 [===========>..................] - ETA: 78scounter: 605
#  596/1406 [===========>..................] - ETA: 78scounter: 606
#  597/1406 [===========>..................] - ETA: 78scounter: 607
#  598/1406 [===========>..................] - ETA: 78scounter: 608
#  599/1406 [===========>..................] - ETA: 78scounter: 609
#  600/1406 [===========>..................] - ETA: 78scounter: 610
#  601/1406 [===========>..................] - ETA: 77scounter: 611
#  602/1406 [===========>..................] - ETA: 77scounter: 612
#  603/1406 [===========>..................] - ETA: 77scounter: 613
#  604/1406 [===========>..................] - ETA: 77scounter: 614
#  605/1406 [===========>..................] - ETA: 77scounter: 615
#  606/1406 [===========>..................] - ETA: 77scounter: 616
#  607/1406 [===========>..................] - ETA: 77scounter: 617
#  608/1406 [===========>..................] - ETA: 77scounter: 618
#  609/1406 [===========>..................] - ETA: 77scounter: 619
#  610/1406 [============>.................] - ETA: 77scounter: 620
#  611/1406 [============>.................] - ETA: 76scounter: 621
#  612/1406 [============>.................] - ETA: 76scounter: 622
#  613/1406 [============>.................] - ETA: 76scounter: 623
#  614/1406 [============>.................] - ETA: 76scounter: 624

# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-23edf3af5c40> in <module>()
#       7                                  verbose=1)
#       8
# ----> 9 print('val_set: ', fbeta_score(np.array(y_val), np.array(p_valid) > 0.2, beta=2, average='samples'))
#      10 #===========================================================================
#
# /usr/local/lib/python2.7/dist-packages/sklearn/metrics/classification.pyc in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight)
#     804                                                  average=average,
#     805                                                  warn_for=('f-score',),
# --> 806                                                  sample_weight=sample_weight)
#     807     return f
#     808
#
# /usr/local/lib/python2.7/dist-packages/sklearn/metrics/classification.pyc in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight)
#    1001         raise ValueError("beta should be >0 in the F-beta score")
#    1002
# -> 1003     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1004     present_labels = unique_labels(y_true, y_pred)
#    1005
#
# /usr/local/lib/python2.7/dist-packages/sklearn/metrics/classification.pyc in _check_targets(y_true, y_pred)
#      70     y_pred : array or indicator matrix
#      71     """
# ---> 72     check_consistent_length(y_true, y_pred)
#      73     type_true = type_of_target(y_true)
#      74     type_pred = type_of_target(y_pred)
#
# /usr/local/lib/python2.7/dist-packages/sklearn/utils/validation.pyc in check_consistent_length(*arrays)
#     179     if len(uniques) > 1:
#     180         raise ValueError("Found input variables with inconsistent numbers of"
# --> 181                          " samples: %r" % [int(l) for l in lengths])
#     182
#     183
#
# ValueError: Found input variables with inconsistent numbers of samples: [5622, 5620]

# %%
p_valid2 = model.predict_generator(batch_generator_test(list(zip(x_valid, y_valid))[-4:], IMG_SIZE, 2, shuffle=False),
                                  steps=2, max_queue_size=1, workers=1, use_multiprocessing=False,
                                 verbose=1)
# Out:
# (4, 2)
# counter: 0
# /home/user/data/amazon_planet/train-jpg/train_24633.jpg
# /home/user/data/amazon_planet/train-jpg/train_22857.jpg
# counter: 1
# /home/user/data/amazon_planet/train-jpg/train_17528.jpg
# /home/user/data/amazon_planet/train-jpg/train_3899.jpg
# 1/2 [==============>...............] - ETA: 0scounter: 0
# /home/user/data/amazon_planet/train-jpg/train_24633.jpg
# /home/user/data/amazon_planet/train-jpg/train_3899.jpg
# 2/2 [==============================] - 0s

# %%
p_valid2
# Out:
# array([], shape=(0, 17), dtype=float32)

# %%
def optimise_f2_thresholds(y, p, verbose=True, resolution=100):
    #credits https://www.kaggle.com/c/planet-understanding-the-amazon-from-space/discussion/32475
  def mf(x):
    p2 = np.zeros_like(p)
    for i in range(17):
      p2[:, i] = (p[:, i] > x[i]).astype(np.int)
    score = fbeta_score(y, p2, beta=2, average='samples')
    return score

  x = [0.2]*17
  for i in range(17):
    best_i2 = 0
    best_score = 0
    for i2 in range(resolution):
      i2 /= resolution
      x[i] = i2
      score = mf(x)
      if score > best_score:
        best_i2 = i2
        best_score = score
    x[i] = best_i2
    if verbose:
      print(i, best_i2, best_score)

  return x

X = optimise_f2_thresholds(np.array(y_val), np.array(p_valid))

# %%
#====================== holdout set est =================================
for f, tags in tqdm(list(zip(x_holdout, y_holdout)), miniters=1000):
    img = cv2.resize(cv2.imread(f), (IMG_SIZE, IMG_SIZE))
    x_hld.append(img)
    y_hld.append(tags)

if len(x_holdout) % 2 > 0:
    x_hld.append(x_hld[0])
    y_hld.append(y_hld[0])

x_hld = np.array(x_hld, np.float16)

p_valid = model.predict(x_hld, batch_size=28, verbose=2)
print('holdout set: ', f2_score(np.array(y_hld), np.array(p_valid) > 0.2))
print('holdout set w/ thresh: ', f2_score(np.array(y_hld), np.array(p_valid) > 0.19))
#===========================================================================
# Out:
# 100%|██████████| 3000/3000 [00:05<00:00, 582.94it/s]
# ('holdout set: ', 0.4228732416922274)
# ('holdout set w/ thresh: ', 0.42908192056572214)

# %%
for f, tags in tqdm(df_test.values, miniters=1000):
    img = TEST_FOLDER + '{}.jpg'.format(f)
    x_test.append(img)

batch_size_test = 32
len_test = len(x_test)
x_tst = []
yfull_test = []
# Out:
# 100%|██████████| 61191/61191 [00:00<00:00, 334137.89it/s]

# %%
TTA_steps = 11

for k in range(0, TTA_steps):
    print(k)
    probs = model.predict_generator(predict_generator(x_test,IMG_SIZE,batch_size_test), steps=np.ceil(len(x_test)/batch_size_test),verbose=1)
    yfull_test.append(probs)
    k += 1

result = np.array(yfull_test[0])

for i in range(1, TTA_steps):
    result += np.array(yfull_test[i])
result /= TTA_steps

res = pd.DataFrame(result, columns=labels)
preds = []

for i in tqdm(range(res.shape[0]), miniters=1000):
    a = res.ix[[i]]
    a = a.apply(lambda x: x > X, axis=1)
    a = a.transpose()
    a = a.loc[a[i] == True]
    ' '.join(list(a.index))
    preds.append(' '.join(list(a.index)))

print(len(preds))
# Out:
# 0(61191, 1913.0)
#
# 1913/1913 [==============================] - 408s
# 1
# (61191, 1913.0)
#  151/1913 [=>............................] - ETA: 374s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-80-c6b9c4a3ccee> in <module>()
#       3 for k in range(0, TTA_steps):
#       4     print(k)
# ----> 5     probs = model.predict_generator(predict_generator(x_test,IMG_SIZE,batch_size_test), steps=np.ceil(len(x_test)/batch_size_test),verbose=1)
#       6     yfull_test.append(probs)
#       7     k += 1
#
# /usr/local/lib/python2.7/dist-packages/Keras-2.0.5-py2.7.egg/keras/legacy/interfaces.pyc in wrapper(*args, **kwargs)
#      85                 warnings.warn('Update your `' + object_name +
#      86                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 87             return func(*args, **kwargs)
#      88         wrapper._original_function = func
#      89         return wrapper
#
# /usr/local/lib/python2.7/dist-packages/Keras-2.0.5-py2.7.egg/keras/engine/training.pyc in predict_generator(self, generator, steps, max_queue_size, workers, use_multiprocessing, verbose)
#    2054
#    2055             while steps_done < steps:
# -> 2056                 generator_output = next(output_generator)
#    2057                 if isinstance(generator_output, tuple):
#    2058                     # Compatibility with the generators
#
# /usr/local/lib/python2.7/dist-packages/Keras-2.0.5-py2.7.egg/keras/utils/data_utils.pyc in get(self)
#     634                     yield inputs
#     635             else:
# --> 636                 time.sleep(self.wait_time)
#
# KeyboardInterrupt:

# %%
result = np.array(yfull_test[0])
result.shape
res = pd.DataFrame(result, columns=labels)
preds = []

for i in tqdm(range(res.shape[0]), miniters=1000):
    a = res.ix[[i]]
    a = a.apply(lambda x: x > 0.19, axis=1)
    a = a.transpose()
    a = a.loc[a[i] == True]
    ' '.join(list(a.index))
    preds.append(' '.join(list(a.index)))

print(len(preds))
# Out:
# 100%|██████████| 61188/61188 [01:58<00:00, 518.05it/s]
# 61188

# %%
df_test['tags'] = preds
# df_test = df_test[:-57]
df_test.to_csv('submission.csv', index=False)

# %%
len(preds)
# Out:
# 61191

# %%
df_test.shape
# Out:
# (61191, 2)

# %%
df_test = df_test[:-43]

# %%
df_test.shape
# Out:
# (61091, 2)
